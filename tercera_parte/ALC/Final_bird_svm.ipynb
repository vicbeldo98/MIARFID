# %%
# !unzip /content/pan22-author-profiling-training-2022-03-29.zip > /dev/null 2>&1
# !unzip /content/pan22-author-profiling-test-2022-04-22-without_truth.zip > /dev/null 2>&1

# %%
import os
import re
import pickle
import numpy as np
from tqdm import tqdm

import xml.etree.ElementTree as ET

from sklearn.metrics import classification_report

# %%
def tokenize_phrase(s, as_list=True):
  xx=[]
  x=s.split()
  for t in x:
    t = t.lower()
    t = re.sub( '#user#', "@USER", t )
    t = re.sub( '#url#', "HTTPURL", t )
    t = re.sub( '#hashtag#', "", t )

    xx.append(t)

  if not as_list:
    return " ".join(xx)
  return (xx)

# %%
train_directory = '/content/pan22-author-profiling-training-2022-03-29/en/'
test_directory = '/content/pan22-author-profiling-test-2022-04-22-without_truth/en/'

def process_truth(path):
  ground_truth = dict()
  with open(path, 'r') as f:
    for line in f:
      elems = line.split(":::")
      user_id = elems[0]
      user_class = elems[1].replace("\n", "")
      ground_truth[user_id] = user_class
  return ground_truth

def get_data_from_xml_file(path):
  tree = ET.parse(path)
  root = tree.getroot()[0]

  user_id = path.split("/")[-1].split(".")[0]
  user_tweets = list()
  for tweet_xml in root:
    tweet = tweet_xml.text
    user_tweets.append( tweet )

  return user_id, user_tweets


train_users_tweets = dict()
for filename in os.listdir(train_directory):
    f = os.path.join(train_directory, filename)
    if os.path.isfile(f) and filename.endswith('.xml'):
        user_id, user_tweets = get_data_from_xml_file(f)
        aux = []
        for tweet in user_tweets:
          aux.append(tokenize_phrase(tweet, as_list=False))
        train_users_tweets[user_id] = aux
    elif os.path.isfile(f):
      ground_truth = process_truth(f)

assert len(train_users_tweets) == len(ground_truth)

n_train_users = len(train_users_tweets)


test_users_tweets = dict()
for filename in os.listdir(test_directory):
    f = os.path.join(test_directory, filename)
    if os.path.isfile(f) and filename.endswith('.xml'):
        user_id, user_tweets = get_data_from_xml_file(f)
        aux = []
        for tweet in user_tweets:
          aux.append(tokenize_phrase(tweet, as_list=False))
        test_users_tweets[user_id] = aux

n_test_users = len(test_users_tweets)

# %%
print(n_train_users, n_test_users)
# Out:
# 420 180

# %%
# Process data, so every user is a string of his tweets and his class

train_data = list()
train_labels = list()

for k in train_users_tweets.keys():
    train_data.append( "\n".join(train_users_tweets[k]) )
    train_labels.append(ground_truth[k])

test_data = list()
test_users = list()

for k in sorted(test_users_tweets.keys()):
    test_data.append( "\n".join(test_users_tweets[k]) )
    test_users.append(k)

# %%
import re

def mi_tokenizador(s, as_list=True):
  xx=[]
  x=s.split()
  for t in x:
    t = t.lower()

    t = re.sub( '#user#', "", t )
    t = re.sub( '#url#', "", t )
    t = re.sub( '#hashtag#', "", t )

    t = re.sub( "[0-9]{1,2}[-/]{1}[0-9]{1,2}[-/]{1}[0-9]{2,4}", "date", t ) # numeric dates
    t = re.sub( "[0-9]+[.,/\-:]{1}[0-9]+|[0-9]+" , "num", t ) # all numbers
    xx.append(t)

  if not as_list:
    return " ".join(xx)
  return (xx)

# %%
from sklearn.feature_extraction.text import CountVectorizer

from sklearn import svm

vectorizer = CountVectorizer(tokenizer=mi_tokenizador)

train_vectors = vectorizer.fit_transform(train_data)
test_vectors = vectorizer.transform(test_data)

classifier_liblinear = svm.LinearSVC(C=100000, max_iter=1000000)

classifier_liblinear.fit(train_vectors, train_labels)
preds = classifier_liblinear.predict(test_vectors)

# %%
print(preds)
# Out:
# ['NI' 'NI' 'NI' 'NI' 'NI' 'I' 'NI' 'I' 'I' 'I' 'NI' 'I' 'NI' 'I' 'I' 'NI'
#  'NI' 'NI' 'I' 'I' 'I' 'NI' 'NI' 'I' 'I' 'I' 'NI' 'I' 'I' 'NI' 'I' 'NI'
#  'I' 'NI' 'NI' 'NI' 'NI' 'I' 'NI' 'NI' 'I' 'I' 'I' 'NI' 'NI' 'I' 'I' 'NI'
#  'I' 'I' 'I' 'I' 'I' 'I' 'I' 'NI' 'I' 'I' 'NI' 'I' 'NI' 'I' 'NI' 'NI' 'NI'
#  'I' 'I' 'I' 'I' 'NI' 'NI' 'I' 'I' 'I' 'I' 'NI' 'I' 'NI' 'I' 'NI' 'NI' 'I'
#  'NI' 'I' 'I' 'I' 'NI' 'NI' 'I' 'I' 'I' 'I' 'I' 'I' 'NI' 'NI' 'NI' 'NI'
#  'NI' 'NI' 'NI' 'NI' 'I' 'NI' 'NI' 'I' 'I' 'NI' 'I' 'NI' 'NI' 'I' 'I' 'I'
#  'I' 'NI' 'I' 'NI' 'I' 'NI' 'I' 'NI' 'I' 'I' 'I' 'NI' 'NI' 'NI' 'I' 'NI'
#  'I' 'I' 'NI' 'NI' 'NI' 'NI' 'I' 'I' 'I' 'NI' 'I' 'NI' 'I' 'NI' 'NI' 'NI'
#  'I' 'I' 'I' 'I' 'I' 'NI' 'NI' 'I' 'NI' 'NI' 'I' 'NI' 'NI' 'I' 'I' 'I' 'I'
#  'NI' 'NI' 'NI' 'I' 'NI' 'NI' 'I' 'I' 'NI' 'NI' 'NI' 'I' 'I' 'I' 'NI' 'I'
#  'I']

# %%
INT_TO_CLASS_LABEL = ["NI", "I"]
CLASS_LABEL_TO_INT = {"NI": 0, "I": 1}

test_counts = [0, 0]

out_file = open("test_truth_final.txt", "w")
for index in range(len(test_users)):
  test_counts[ CLASS_LABEL_TO_INT[preds[index]] ] += 1
  out_file.write(f"{test_users[index]}:::{preds[index]}\n")
out_file.close()

print(f"Hemos predecido un total de {test_counts[0]} usuarios no irónicos y {test_counts[1]} irónicos.")
# Out:
# Hemos predecido un total de 85 usuarios no irónicos y 95 irónicos.

# %%
import os
import xml.etree.cElementTree as ET

INT_TO_CLASS_LABEL = ["NI", "I"]
test_users_predicts = dict()
for index in range(len(test_users)):
  test_users_predicts[test_users[index]] = preds[index]

test_result_directory = "./truth_final"
if not os.path.isdir(test_result_directory):
  os.mkdir(test_result_directory)

for test_user, classif_class in test_users_predicts.items():
  out_user = open( os.path.join(test_result_directory, f"{test_user}.xml") , "w")
  out_user.write(f'<author id="{test_user}"\nlang="en"\ntype="{classif_class}"\n/>')
  out_user.close()

# %%
# !ls ./truth_final | wc -l
# Out:
# 180

# %%
# !zip -r truth_final.zip ./truth
# Out:
#   adding: truth/ (stored 0%)
#   adding: truth/676ac6f0f8dc64239691d8052409a54c.xml (stored 0%)
#   adding: truth/edaecf3e231cbefe0a7af13a6b92a21f.xml (stored 0%)
#   adding: truth/ffc409cdad92bf2d15f4a9e18b250b31.xml (stored 0%)
#   adding: truth/bfa500f8b9ccbe67ad0665ce4d542684.xml (stored 0%)
#   adding: truth/ba5c2b0d20b249842b210ccdb6b4c3e4.xml (stored 0%)
#   adding: truth/8158fecf0e49ac5f3cc14b821340a9e7.xml (stored 0%)
#   adding: truth/3f016b5c991cdf30d875bdd7169cf345.xml (stored 0%)
#   adding: truth/d6006abecde419c59ba33532dd533e2b.xml (stored 0%)
#   adding: truth/740c19c02e8aefb4ee35febedd3777a2.xml (stored 0%)
#   adding: truth/c554db6744829b2a0a04d8b774a5edcb.xml (stored 0%)
#   adding: truth/a59360a9459f133a101abd69393b29eb.xml (stored 0%)
#   adding: truth/e997fcccff44cb6744640e8b9d187a15.xml (stored 0%)
#   adding: truth/2550b4037ef6eef0b337d9146b13fa89.xml (stored 0%)
#   adding: truth/691bbc00ee1d62d71a5a6115cf356600.xml (stored 0%)
#   adding: truth/65f1a4dbac4543ca70b201c9b6cb098e.xml (stored 0%)
#   adding: truth/31fb0062735f47c1fb9a6e6c6edebd5c.xml (stored 0%)
#   adding: truth/4d8ae2f1f0f57e1b55bd261fb183371c.xml (stored 0%)
#   adding: truth/e59cae77d833f47f5673f0628cbfb69.xml (stored 0%)
#   adding: truth/816fc853eb4164035f1c948cf4951887.xml (stored 0%)
#   adding: truth/6e1648fed5478f5804e61df477cf0eba.xml (stored 0%)
#   adding: truth/2d6335cf6d30263335be06d2c16ffba3.xml (stored 0%)
#   adding: truth/f2d1159fb500659a68dbffeafd9e0260.xml (stored 0%)
#   adding: truth/593815e5b9d1c9f9590bac699ceaac33.xml (stored 0%)
#   adding: truth/5f8a782d4ef21f64b7e28f1aa1baf7fb.xml (stored 0%)
#   adding: truth/5ed92b7c6b4c0a1cde0baa014b55506.xml (stored 0%)
#   adding: truth/d128b269e54f4cda04bb2591b8cc0b3b.xml (stored 0%)
#   adding: truth/7eb12463f86d376f7fc98f0932efd07b.xml (stored 0%)
#   adding: truth/e39879d03b48e0125d7c8cccdc76a688.xml (stored 0%)
#   adding: truth/9b838af92dfe5f1a2df902c5cca8462e.xml (stored 0%)
#   adding: truth/4a9cc50e0ff013954925d37b8b19d767.xml (stored 0%)
#   adding: truth/18cab06282ac3225d75b2cdafde1520b.xml (stored 0%)
#   adding: truth/b122a34fb26c64ff4f238b2c18367264.xml (stored 0%)
#   adding: truth/a66f4d6aacab429f325ecd54f40511f5.xml (stored 0%)
#   adding: truth/893cba19b29b2e17951d6acf43b2c45.xml (stored 0%)
#   adding: truth/44401ac9a8880f9856f831975a1370b1.xml (stored 0%)
#   adding: truth/a1eb3ef34d8529b75bdf9791d028ec15.xml (stored 0%)
#   adding: truth/e7c483757d3b241d44661775d40dab2d.xml (stored 0%)
#   adding: truth/40e912928628503bc270e942d303208b.xml (stored 0%)
#   adding: truth/f9fcccbcded1a4064a29df6d2d525453.xml (stored 0%)
#   adding: truth/e8024eac515154e20f9cf3df1305d67d.xml (deflated 1%)
#   adding: truth/ac06a70c4b18ec54d5cb01e73d8ca4a8.xml (stored 0%)
#   adding: truth/8a030f3bbfcf12db415cd1b19c69dbd8.xml (stored 0%)
#   adding: truth/d2da4788f1aeb276d19e5b132239052.xml (stored 0%)
#   adding: truth/78e70dd9326c5b7dbaeb371a9b8bf126.xml (stored 0%)
#   adding: truth/1f5029dd2995ed09fd4f7487c9255375.xml (stored 0%)
#   adding: truth/c3c06e0097a689a9df6f4a93fa01133b.xml (stored 0%)
#   adding: truth/a4f728bf929a78edb51642c562c013ec.xml (stored 0%)
#   adding: truth/cdd92eb23c1b4ae25699cfc3f6477e40.xml (stored 0%)
#   adding: truth/1a1f45cdfe6d25473a0bd7242c378878.xml (stored 0%)
#   adding: truth/1a244c1cfcef5fea89af4e3643c16f21.xml (stored 0%)
#   adding: truth/58fe18c2d89ad3245e6521426d7fc3e7.xml (stored 0%)
#   adding: truth/b660f1eee1f7acc9f14e2c493b07cf2a.xml (stored 0%)
#   adding: truth/786b4fa4808787702e6531481f7eb607.xml (stored 0%)
#   adding: truth/366e720d4c675992b50663260429c88e.xml (stored 0%)
#   adding: truth/521539c16fa321b38153cfa4e443d2b9.xml (stored 0%)
#   adding: truth/e9f41771f90608df26e5788b50260bc9.xml (stored 0%)
#   adding: truth/cfe6388d306c222c57451488a15912cc.xml (stored 0%)
#   adding: truth/146a26134931e1770af27c20bb4acfa8.xml (stored 0%)
#   adding: truth/c3da6cddfa60b064a3be4b72298a4cf6.xml (stored 0%)
#   adding: truth/a20802d4e38a181ed71a4a2c85c2bafe.xml (stored 0%)
#   adding: truth/28cab8047dba4722aeca734f3ddc4eec.xml (stored 0%)
#   adding: truth/b223257b24899d76b2c0f20433432c8b.xml (stored 0%)
#   adding: truth/8891c5e078a5a0fb31165fab403f8f02.xml (stored 0%)
#   adding: truth/3db3d232cde8ccede9e3138a660e6a4c.xml (stored 0%)
#   adding: truth/a46e5a901b594c2161de8b352a45b3e3.xml (stored 0%)
#   adding: truth/43fabf267223ad4c8a4fbff8b57e4b8a.xml (stored 0%)
#   adding: truth/cc63c60166c21d03acb3ff1b2e7d3522.xml (stored 0%)
#   adding: truth/b7dd38b00e193a02ee43240b1aebbba.xml (stored 0%)
#   adding: truth/17b5a5c1673335c4b3b9753fa7e194de.xml (stored 0%)
#   adding: truth/969d2dba2d508cc84edbbae4648dd286.xml (stored 0%)
#   adding: truth/9228dac155633b13780552bc01dc2e0.xml (stored 0%)
#   adding: truth/99ef32070fa9ea7e5952193b1b50dafc.xml (stored 0%)
#   adding: truth/5f1c24718e8e3f71a122e27e89043770.xml (stored 0%)
#   adding: truth/a82d542c0362bce020d88532331575a0.xml (stored 0%)
#   adding: truth/df9e77676844c1fda46ad4534b4767e5.xml (stored 0%)
#   adding: truth/fa1a34e452813e1c4fac7c88df1805ef.xml (stored 0%)
#   adding: truth/199b3fb39de3ef20bda586a7a7ef8932.xml (stored 0%)
#   adding: truth/7d152fc274395994032a5cff4d5dbba6.xml (stored 0%)
#   adding: truth/ffc8184d3f3fec0e5b5b42c22d86da2a.xml (stored 0%)
#   adding: truth/aeb3d694bd1965026c03fa807e863051.xml (stored 0%)
#   adding: truth/650ee7dd8e02bce6e14acdcf0d58e531.xml (stored 0%)
#   adding: truth/d11b9be29dc6aefb22929c2c31bbd478.xml (stored 0%)
#   adding: truth/1cb065415cfe7032aa14f13b55421b1c.xml (stored 0%)
#   adding: truth/2317ff2a2ceadee15636052c1399c7f8.xml (stored 0%)
#   adding: truth/559416633fe15b3e5e3096bd53b9d631.xml (stored 0%)
#   adding: truth/7daf7b91e6f0f2abc4423e950349c9ef.xml (stored 0%)
#   adding: truth/dbb395e9db8c0578832077a3df2f5816.xml (stored 0%)
#   adding: truth/2512304c7a847489ea0e561dd34df86a.xml (stored 0%)
#   adding: truth/66a7239d1de4630c834b7d0b435cbd0b.xml (stored 0%)
#   adding: truth/9e2ed1159570f17dbc22eb0849dc53a.xml (stored 0%)
#   adding: truth/de55073df4ac9416d86a5cd5ed299494.xml (stored 0%)
#   adding: truth/ce1b06f36668e710adedb0df10e5dc0d.xml (stored 0%)
#   adding: truth/c002590a0e57aa4f047660c81dff30a7.xml (stored 0%)
#   adding: truth/11af5d73a6168f5d449788d432d3a71c.xml (stored 0%)
#   adding: truth/fcbaffc5ba58f03fd938bd5b97997e76.xml (stored 0%)
#   adding: truth/3ec80b6e0f2e45682db3fb6db73fc6bb.xml (stored 0%)
#   adding: truth/e459387ff746d7a06dd864fb2cf17c38.xml (stored 0%)
#   adding: truth/2452079a6e3be727e87b40afda78d16a.xml (stored 0%)
#   adding: truth/4f1e3f9dfe872d28e59168b3e1756905.xml (stored 0%)
#   adding: truth/2851d0fdd0aa308a35c2ad21a203dbb5.xml (stored 0%)
#   adding: truth/f537b5b7c8960f601afc4a473a28f07d.xml (stored 0%)
#   adding: truth/fafd37354efa9cf8948482619e1cc0f.xml (stored 0%)
#   adding: truth/1272428df3ae67f538fb0f7b3e0f3f6c.xml (stored 0%)
#   adding: truth/2e3aee00b796b86dbec6485e5551f406.xml (stored 0%)
#   adding: truth/b3ca53789d1f41d1fc0e6ebe2847b0c5.xml (stored 0%)
#   adding: truth/fa9b6e8ca23261ba9b072943cf1a7c10.xml (stored 0%)
#   adding: truth/ebc12c72878213b4454d2f6ccdb708d.xml (stored 0%)
#   adding: truth/b8e464af2fb5e8fddef5658c93d3084a.xml (stored 0%)
#   adding: truth/24af070245c0775f6ac1f7bc871b7095.xml (stored 0%)
#   adding: truth/a7fe4d4ea5c58fed2bae8577e1f12b07.xml (stored 0%)
#   adding: truth/721840aac44856765aa21a1bc3510901.xml (stored 0%)
#   adding: truth/188b8b2b9f46999c832bcf2fad3610d9.xml (stored 0%)
#   adding: truth/26ee44cb86041c839c63b362615c099f.xml (stored 0%)
#   adding: truth/d6e240638b048e7c65ec3b1c6c3f4e7c.xml (stored 0%)
#   adding: truth/124b8295f6a00d05825c229a39207586.xml (stored 0%)
#   adding: truth/60757b362e2cdbfd4876a43c7c7abec0.xml (stored 0%)
#   adding: truth/5a6ae0a166ea678f5289e0db930206f1.xml (stored 0%)
#   adding: truth/5cdd0bc06b4d74cbea390a0e519aecf1.xml (stored 0%)
#   adding: truth/55cc89ad573fe23d444d76c1f091428b.xml (stored 0%)
#   adding: truth/a64545c5aaa80f83fef3777224a713af.xml (stored 0%)
#   adding: truth/4ad445aa199855225989d4d80c7641ca.xml (stored 0%)
#   adding: truth/d53275e89bd24a8e6de31555f4d1bffe.xml (stored 0%)
#   adding: truth/8947949be2bb85a177daa9be7de6d568.xml (stored 0%)
#   adding: truth/e78c14a264bf00eb3517b17df72b7f06.xml (stored 0%)
#   adding: truth/2da5a57519c1cbf590ad288717294240.xml (stored 0%)
#   adding: truth/77c203e1abf9c5d9baeef6bf48dc2b4.xml (stored 0%)
#   adding: truth/ee9243423d6bff6ba61fd50c180cc5d.xml (stored 0%)
#   adding: truth/c1affe96dec0745b07886970920b611e.xml (stored 0%)
#   adding: truth/adffc03a24821573a316e2077cd75ba1.xml (stored 0%)
#   adding: truth/c389444098a230b8c4914cb0bf33781.xml (stored 0%)
#   adding: truth/d0c79ce811617b4677cb8b2f7985ea7f.xml (stored 0%)
#   adding: truth/b35705626583155381ee656c7c98248b.xml (stored 0%)
#   adding: truth/f387d4cd681327103dfc4b93c8063596.xml (stored 0%)
#   adding: truth/100ff179983b65bf748ebc64f2966cda.xml (stored 0%)
#   adding: truth/77609b4ce6df60172b4156a1dfddd3de.xml (stored 0%)
#   adding: truth/615dd61ccf928fbf9e15822ad72012f0.xml (stored 0%)
#   adding: truth/7e48ca4f8c1336370ab8b2b853f06c08.xml (stored 0%)
#   adding: truth/34a758e10454a74db3c8654a96e836c9.xml (deflated 1%)
#   adding: truth/24600a384b406eca712d7d2c64ffd128.xml (stored 0%)
#   adding: truth/821aca97820fffa344f36c04ecc76977.xml (stored 0%)
#   adding: truth/925754818a824e30d43c32f4a06ad88d.xml (stored 0%)
#   adding: truth/17cf5a70d4e3ade4e4e031fc0818626e.xml (stored 0%)
#   adding: truth/7d9d096f08714768b743f91bef985505.xml (stored 0%)
#   adding: truth/e0101b9a8cab52021cd8db0510d517bb.xml (stored 0%)
#   adding: truth/1337cd846e2b71e353442d641e5acec4.xml (stored 0%)
#   adding: truth/851542393660bafcd57734a91be6a9bf.xml (stored 0%)
#   adding: truth/3a439aff76fd834539ebf05db59e948.xml (stored 0%)
#   adding: truth/eb89e7af90cb12354b410f8123d7f580.xml (deflated 1%)
#   adding: truth/8273c259428ab10f60e0deab7db3aebd.xml (stored 0%)
#   adding: truth/56735358708e859a59bced6cdf911ef2.xml (stored 0%)
#   adding: truth/6813794d2077d27b1bc7be4b16f95709.xml (stored 0%)
#   adding: truth/4b43a97997709a90b523712cd4178760.xml (stored 0%)
#   adding: truth/d924effc8dfdcb1046a46860d089c1af.xml (stored 0%)
#   adding: truth/ad01bfeae7550f809e2a6d31a08e4572.xml (stored 0%)
#   adding: truth/c32bf7ecce95dd084f17e76f5c3d11c2.xml (stored 0%)
#   adding: truth/a85a9e752b1c7c3e01d300c5e19c6d98.xml (stored 0%)
#   adding: truth/85c7fc3467f162a0ae4b4e4ea0c93844.xml (stored 0%)
#   adding: truth/fbe0f8f92e609789a5d968f01787b8ca.xml (stored 0%)
#   adding: truth/aff307c6397a566f998178f78fc516a2.xml (stored 0%)
#   adding: truth/f291520f4048cf72e0b2a61191c7dff2.xml (stored 0%)
#   adding: truth/58e5bea5c4ed3b543ed1a4a8801aea2.xml (stored 0%)
#   adding: truth/35206cb65f916c8390d9ef7a31cb6e01.xml (stored 0%)
#   adding: truth/4fa90de2c3076b6e056b4db792cad7b.xml (stored 0%)
#   adding: truth/675d2a8808715441d0ffcf41a38d0106.xml (stored 0%)
#   adding: truth/3c9414fee09220ce354f549552d6e92.xml (stored 0%)
#   adding: truth/d37b5fc2bf89a4fad468d2db5bb27ed1.xml (stored 0%)
#   adding: truth/e05c79172e495bb4899d36f2d83b81a6.xml (stored 0%)
#   adding: truth/e86604f8bd08b574bfda3182e2767a22.xml (stored 0%)
#   adding: truth/bb06a89aa2a4034225d7f5143a6f4c8d.xml (stored 0%)
#   adding: truth/2a93f92159ab9988675fa8c0cc4e0496.xml (stored 0%)
#   adding: truth/256c393d24578b54e62a704b61e507c0.xml (stored 0%)
#   adding: truth/6e36cbaf011d7928190a0f18edede807.xml (stored 0%)
#   adding: truth/68b7640850e2324390bfb1d061fa578d.xml (stored 0%)
#   adding: truth/17d5240b3616194baf205739c76e7a72.xml (stored 0%)
#   adding: truth/ed3b599351e3355ef2f0b25b5c9f5e49.xml (stored 0%)
#   adding: truth/27da3cd0e6f358e567326d4f05044779.xml (stored 0%)
#   adding: truth/13c0827671f407ed45e78b0b5c5b793f.xml (stored 0%)
#   adding: truth/80e46d56a7ada130a26e9159e38604f3.xml (stored 0%)
#   adding: truth/4280523c525874566e34aa01c451b03f.xml (stored 0%)
#   adding: truth/5868d86536f3dd3cedab9724edd344ae.xml (stored 0%)
